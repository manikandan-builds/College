# %%
import torch
import torchvision
import cv2
# from IPython.display import Image
# import matplotlib.pyplot as plt
import numpy as np

# %%
yolov5 = torch.hub.load("ultralytics/yolov5", "yolov5s", pretrained=True)
# Out:
# Using cache found in C:\Users\22bad045/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-2-18 Python-3.10.7 torch-2.6.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
test_img_path = r"C:\Users\22bad045\Desktop\person.jpg"

# %%
detected_results = yolov5(test_img_path)
detected_results.print()
# Out:
# C:\Users\22bad045/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 180x225 1 person, 1 car
# Speed: 27.7ms pre-process, 128.8ms inference, 0.0ms NMS per image at shape (1, 3, 512, 640)

# %%
detected_results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=225x180>
